# %%
# Import Dependences
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# Retrieve file path
file_path = Path('../Resources/cancer patient data sets.xlsx')

# %%
# Read File
df = pd.read_excel(file_path)

# %%
# Check file content
df.head()
# Out:
#   Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0         P1   33       1              2            4             5
# 1        P10   17       1              3            1             5
# 2       P100   35       1              4            5             6
# 3      P1000   37       1              7            7             7
# 4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# ...

# %%
# Replace numerical values with labels
df['Gender'] = df['Gender'].replace({1: 'male', 2: 'female'})

# Display the updated DataFrame
df
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33    male              2            4             5
# 1          P10   17    male              3            1             5
# 2         P100   35    male              4            5             6
# 3        P1000   37    male              7            7             7
# 4         P101   46    male              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44    male              6            7             7
# 996       P996   37  female              6            8             7
# 997       P997   25  female              4            5             6
# 998       P998   18  female              6            8             7
# 999       P999   47    male              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
# Set index to dataframe
df = df.set_index('Patient Id')

# %%
df['Balanced Diet'].value_counts()
# Out:
# Balanced Diet
# 7    296
# 2    231
# 3    173
# 6    159
# 4     61
# 5     40
# 1     40
# Name: count, dtype: int64

# %%
# PNG File storage prep
folder_path = 'images'
file_name = 'dietary_habits.png'

# Parameters for pie chart
labels = ["1", "2", "3", "4", "5", "6", "7"]
sizes = [40, 40, 61, 159, 173, 231, 296]
explode = (0, 0, 0, 0, 0 , 0, 0.1)
colors = ["red", "orange", "lightskyblue", "purple", "yellow", "blue", "darkgreen"]

# Pie chart of Dietary Habits
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140) 
plt.show

# Storing PNG
file_path = os.path.join(folder_path, file_name)
plt.savefig(file_path)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# male      598
# female    402
# Name: count, dtype: int64

# %%
# PNG File storage prep
folder_path = 'images'
file_name = 'Cancer_Patients_by_Gender.png'

# Parameters for pie chart
labels = ["Male", "Female"]
sizes = [598, 402]
colors = ["blue", "pink"]
explode = (0.1, 0)

# Pie chart for gender
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.show

# Storing PNG
file_path = os.path.join(folder_path, file_name)
plt.savefig(file_path)

# %%
df['Obesity'].value_counts()
# Out:
# Obesity
# 7    356
# 3    193
# 4    191
# 2    140
# 1     70
# 6     30
# 5     20
# Name: count, dtype: int64

# %%
# PNG File storage prep
folder_path = 'images'
file_name = 'Obesity_rates.png'

# Parameters for pie chart
labels = ["1", "2", "3", "4", "5", "6", "7"]
sizes = [70, 140, 193, 191, 20, 30, 356]
explode = (0, 0, 0, 0, 0 , 0, 0.1)
colors = ["red", "orange", "lightskyblue", "purple", "yellow", "blue", "darkgreen"]

# Pie chart of Dietary Habits
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140) 
plt.show

# Storing PNG
file_path = os.path.join(folder_path, file_name)
plt.savefig(file_path)

# %%
df
# Out:
#             Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# Patient Id
# P1           33    male              2            4             5
# P10          17    male              3            1             5
# P100         35    male              4            5             6
# P1000        37    male              7            7             7
# P101         46    male              6            8             7
# ...         ...     ...            ...          ...           ...
# P995         44    male              6            7             7
# P996         37  female              6            8             7
# P997         25  female              4            5             6
# P998         18  female              6            8             7
# P999         47    male              6            5             6
#
#             OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# Patient Id
# P1                             4             3                     2
# ...

# %%
# Retrive the 'Age' column to prep for binning
for_binning = df['Age']
for_binning
# Out:
# Patient Id
# P1       33
# P10      17
# P100     35
# P1000    37
# P101     46
#          ..
# P995     44
# P996     37
# P997     25
# P998     18
# P999     47
# Name: Age, Length: 1000, dtype: int64

# %%
# Create new dataframe for binning
binning_df = pd.DataFrame(for_binning)
binning_df
# Out:
#             Age
# Patient Id
# P1           33
# P10          17
# P100         35
# P1000        37
# P101         46
# ...         ...
# P995         44
# P996         37
# P997         25
# P998         18
# P999         47
#
# [1000 rows x 1 columns]

# %%
# Create bins
bins = [0, 20, 30, 40, 50, 60, 70, 80]

# Create group names
group_names = ["0-20", "21-30", "31-40", "41-50", "51-60", "61-70", "71-80"]

# Create new dataframe with bins
binning_df['Age_range'] = pd.cut(df['Age'], bins, labels=group_names)
binning_df
# Out:
#             Age Age_range
# Patient Id
# P1           33     31-40
# P10          17      0-20
# P100         35     31-40
# P1000        37     31-40
# P101         46     41-50
# ...         ...       ...
# P995         44     41-50
# P996         37     31-40
# P997         25     21-30
# P998         18      0-20
# P999         47     41-50
#
# [1000 rows x 2 columns]

# %%
# Create new dataframe categorized by age ranges
age_range_df = pd.DataFrame(binning_df["Age_range"].value_counts())
age_range_df
# Out:
#            count
# Age_range
# 31-40        358
# 21-30        234
# 41-50        207
# 0-20          67
# 51-60         63
# 61-70         61
# 71-80         10

# %%
age_range_df = age_range_df.sort_index()

# %%
age_range_df.index
# Out:
# CategoricalIndex(['0-20', '21-30', '31-40', '41-50', '51-60', '61-70',
#                   '71-80'],
#                  categories=['0-20', '21-30', '31-40', '41-50', '51-60', '61-70', '71-80'], ordered=True, dtype='category', name='Age_range')

# %%
# PNG File storage prep
folder_path = 'images'
file_name = 'bargraph_age_range.png'

x_axis = age_range_df.index
y_axis = age_range_df['count']
colors = ['lightgreen'] * len(age_range_df)
darker_bar_index = 2
colors[darker_bar_index] = 'darkgreen'

# Using the new dataframe to plot age ranges among cancer patients
plt.bar(x_axis, y_axis, color = colors, alpha=0.5, align="center")
plt.xlabel('Age Range')
plt.ylabel('Count')
plt.title('Cancer Patients by Age')
# age_range_df.plot(kind='bar', y='count')
# plt.title('Ages Among Cancer Patients')
# plt.xlabel('Age Range')
# plt.ylabel('Count')

# Storing PNG
file_path = os.path.join(folder_path, file_name)
plt.savefig(file_path)

# Displaying graph
plt.show()
